# %%
import pandas as pd

# %%
nov_22 = pd.read_csv('Data/JC-202211-citibike-tripdata.csv')
nov_22
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      7B06EEA21608591A   classic_bike  2022-11-12 14:47:21
# 1      B22A3E8765F1E165   classic_bike  2022-11-30 08:29:53
# 2      CFB2EB1663C02BB6  electric_bike  2022-11-09 08:28:30
# 3      85700816DAAE1C36  electric_bike  2022-11-30 14:48:11
# 4      009EBB1F54C5947E  electric_bike  2022-11-10 18:14:33
# ...                 ...            ...                  ...
# 72704  5CD09DFD050326DF   classic_bike  2022-11-04 15:42:11
# 72705  99BEB76F3AF420D6   classic_bike  2022-11-13 11:42:30
# 72706  784CC6A8F182DE26  electric_bike  2022-11-05 01:33:31
# 72707  E3CBD5C6006BE3E2   classic_bike  2022-11-18 19:11:27
# 72708  DBDEE1728FAA6730   classic_bike  2022-11-07 17:43:50
#
#                   ended_at start_station_name start_station_id  \
# 0      2022-11-12 14:58:55       Newport PATH            JC066
# 1      2022-11-30 08:45:56       Newport PATH            JC066
# ...

# %%
dec_22 = pd.read_csv('Data/JC-202212-citibike-tripdata.csv')
dec_22
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      099D81CA71EBADAB   classic_bike  2022-12-23 16:02:26
# 1      D979F3B79FC30F1F  electric_bike  2022-12-27 10:54:29
# 2      3950909BC3B42E43   classic_bike  2022-12-31 10:39:39
# 3      372E50F5FB4FD434   classic_bike  2022-12-05 08:16:10
# 4      AB701FB8091C7431   classic_bike  2022-12-02 13:40:36
# ...                 ...            ...                  ...
# 48580  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 48581  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 48582  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 48583  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 48584  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                   ended_at                      start_station_name  \
# 0      2022-12-23 16:09:40  Mama Johnson Field - 4 St & Jackson St
# 1      2022-12-27 10:59:23                            Jersey & 3rd
# ...

# %%
merged_novdec22 = pd.concat([nov_22,dec_22],ignore_index=True)
merged_novdec22
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       7B06EEA21608591A   classic_bike  2022-11-12 14:47:21
# 1       B22A3E8765F1E165   classic_bike  2022-11-30 08:29:53
# 2       CFB2EB1663C02BB6  electric_bike  2022-11-09 08:28:30
# 3       85700816DAAE1C36  electric_bike  2022-11-30 14:48:11
# 4       009EBB1F54C5947E  electric_bike  2022-11-10 18:14:33
# ...                  ...            ...                  ...
# 121289  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 121290  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 121291  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 121292  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 121293  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                    ended_at                      start_station_name  \
# 0       2022-11-12 14:58:55                            Newport PATH
# 1       2022-11-30 08:45:56                            Newport PATH
# ...

# %%
# Check the datatypes of your columns. 
merged_novdec22.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
# Convert the 'tripduration' column to datetime datatype.
merged_novdec22['tripduration'] = pd.to_datetime(citibike_NYC_201908_df['tripduration'], unit='s')

# %%
merged_novdec22.to_csv('Data/merged_novdec22.csv', index=False)
